# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 83.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
! unzip "Face Mask.v18i.yolov8.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/images/maksssksksss836_png.rf.38d069af09fb18ea408b5e74de76ae9d.jpg
#  extracting: train/images/maksssksksss838_png.rf.a8f881b3c03f4b966222d81a520b8530.jpg
#  extracting: train/images/maksssksksss840_png.rf.f72ec498b1301b4d7975f782162180bc.jpg
#  extracting: train/images/maksssksksss843_png.rf.7dba90c3fa4317434faa4f52755c62f0.jpg
#  extracting: train/images/maksssksksss844_png.rf.141ba651f6f6b8c208e4ad363bdd83bb.jpg
#  extracting: train/images/maksssksksss845_png.rf.3ea4fd3c77b382c36119ac690888770d.jpg
#  extracting: train/images/maksssksksss846_png.rf.1235fe2c42dddaa1f7b50c8301388c1f.jpg
#  extracting: train/images/maksssksksss847_png.rf.35880af3f2b7955539fc1fce2d4ec53c.jpg
#  extracting: train/images/maksssksksss848_png.rf.7cf77b1717d40e623978bd3367804b84.jpg
#  extracting: train/images/maksssksksss84_png.rf.5e5aa03fe3b119614307f1334418809b.jpg
# ...

# %%
from ultralytics import YOLO
model=YOLO("yolov8n.pt")

# %%
model.train(
    data='data.yaml',
    epochs=20,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.3.252 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO("runs/detect/train/weights/best.pt")
model.predict(source="/content/ChatGPT Image Jan 11, 2026, 04_43_03 PM.png", conf=0.4, save=True, show=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/ChatGPT Image Jan 11, 2026, 04_43_03 PM.png: 448x640 5 Masques, 2 PasMasques, 8.8ms
# Speed: 2.6ms preprocess, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict4
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Masque', 1: 'Notcorrect', 2: 'PasMasque'}
#  obb: None
#  orig_img: array([[[117, 115, 115],
#          [116, 114, 114],
#          [115, 113, 113],
#          ...,
#          [ 41,  58,  77],
#          [ 47,  61,  80],
#          [  0,   0,  14]],
#
#         [[121, 119, 119],
#          [120, 118, 118],
#          [119, 117, 117],
#          ...,
#          [ 43,  60,  81],
#          [ 47,  62,  81],
#          [  0,   0,  14]],
#
#         [[124, 122, 122],
#          [124, 122, 122],
# ...

# %%
from IPython.display import Image, display

# The path shown in your console output
image_path = "/content/runs/detect/predict4/ChatGPT Image Jan 11, 2026, 04_43_03 PM.jpg"

display(Image(filename=image_path))

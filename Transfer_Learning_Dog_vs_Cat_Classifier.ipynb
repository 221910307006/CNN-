# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# %%
img_size = (224, 224)
batch_size = 32

train_data = datagen.flow_from_directory(
    'animals',
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary',
    subset='training'
)

val_data = datagen.flow_from_directory(
    'animals',
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary',
    subset='validation'
)
# Out:
# Found 796 images belonging to 2 classes.
# Found 199 images belonging to 2 classes.

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.applications import ResNet50

# %%
base_model = ResNet50(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
base_model.trainable = False

# %%
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(128, activation="relu"),
    Dropout(0.2),
    Dense(1, activation="sigmoid")
])

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=10
)
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 514ms/step - accuracy: 0.7489 - loss: 0.5223 - val_accuracy: 0.8090 - val_loss: 0.5027
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 481ms/step - accuracy: 0.7743 - loss: 0.5035 - val_accuracy: 0.7990 - val_loss: 0.4845
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 475ms/step - accuracy: 0.7845 - loss: 0.4869 - val_accuracy: 0.8040 - val_loss: 0.4706
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 476ms/step - accuracy: 0.8145 - loss: 0.4609 - val_accuracy: 0.6985 - val_loss: 0.5363
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 468ms/step - accuracy: 0.7789 - loss: 0.4901 - val_accuracy: 0.7839 - val_loss: 0.4767
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 483ms/step - accuracy: 0.7874 - loss: 0.4595 - val_accuracy: 0.8040 - val_loss: 0.4374
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 478ms/step - accuracy: 0.8172 - loss: 0.4172 - val_accuracy: 0.8291 - val_loss: 0.4169
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 478ms/step - accuracy: 0.8270 - loss: 0.4065 - val_accuracy: 0.8090 - val_loss: 0.4253
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 480ms/step - accuracy: 0.8685 - loss: 0.3629 - val_accuracy: 0.8291 - val_loss: 0.4039
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 487ms/step - accuracy: 0.8768 - loss: 0.3522 - val_accuracy: 0.8291 - val_loss: 0.3952

# %% [markdown]
# VGG16 model for Transfer Learning

# %%
from tensorflow.keras.applications import VGG16
vgg16 = VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(224, 224, 3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
for layer in vgg16.layers:
    layer.trainable = False

# %%
model = Sequential([
    vgg16,
    Flatten(),
    Dense(256, activation="relu"),
    Dropout(0.5),
    Dense(train_data.num_classes, activation="softmax")
])

# %%
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(128, activation="relu"),
    Dropout(0.2),
    Dense(1, activation="sigmoid")
])

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=10
)
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 31s 861ms/step - accuracy: 0.4752 - loss: 0.8226 - val_accuracy: 0.5879 - val_loss: 0.6503
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 493ms/step - accuracy: 0.5476 - loss: 0.6707 - val_accuracy: 0.7337 - val_loss: 0.6067
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 491ms/step - accuracy: 0.7025 - loss: 0.6080 - val_accuracy: 0.7940 - val_loss: 0.5695
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 489ms/step - accuracy: 0.7195 - loss: 0.5772 - val_accuracy: 0.7889 - val_loss: 0.5428
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 489ms/step - accuracy: 0.7787 - loss: 0.5326 - val_accuracy: 0.7538 - val_loss: 0.5319
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 486ms/step - accuracy: 0.7883 - loss: 0.5124 - val_accuracy: 0.8090 - val_loss: 0.4929
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 487ms/step - accuracy: 0.7848 - loss: 0.5007 - val_accuracy: 0.8090 - val_loss: 0.4869
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 489ms/step - accuracy: 0.8308 - loss: 0.4600 - val_accuracy: 0.7588 - val_loss: 0.4763
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 485ms/step - accuracy: 0.7974 - loss: 0.4531 - val_accuracy: 0.7186 - val_loss: 0.5045
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 490ms/step - accuracy: 0.8196 - loss: 0.4213 - val_accuracy: 0.7990 - val_loss: 0.4368
